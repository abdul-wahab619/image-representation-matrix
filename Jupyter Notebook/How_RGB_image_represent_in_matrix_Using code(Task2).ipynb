# %% [markdown]
# **How RGB image represent in matrix Using code**

# %% [markdown]
# **Import Libraries**

# %%
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# **Function to load and display an RGB image**

# %%
def display_rgb_image(image_path):
    # Open the RGB image
    rgb_image = Image.open(image_path)

    # Convert the image to a NumPy array
    image_array = np.array(rgb_image)

    # Display the RGB image using Matplotlib
    plt.imshow(image_array)
    # plt.axis('off')
    plt.title("RGB Image")
    plt.show()

    #Print the shape and matrix representation of the RGB image
    print("Shape of RGB Image Array:", image_array.shape)
    print("Matrix Representation of RGB Image:")
    print(image_array)

# %% [markdown]
# **Path of RGB image file**

# %%
image_path = '/content/ball.jpg'
display_rgb_image(image_path)
# Out:
# Shape of RGB Image Array: (2160, 3840, 3)
# Matrix Representation of RGB Image:
# [[[149 221 255]
#   [145 217 255]
#   [143 215 253]
#   ...
#   [146 218 255]
#   [149 221 255]
#   [151 223 255]]
#
#  [[144 216 254]
#   [142 214 252]
#   [141 213 251]
#   ...
#   [146 218 255]
#   [148 220 255]
#   [149 221 255]]
#
#  [[146 218 255]
#   [146 218 255]
#   [145 217 255]
#   ...
#   [146 218 255]
#   [146 218 255]
#   [147 219 255]]
#
#  ...
#
#  [[255 205  60]
#   [252 201  56]
#   [248 197  52]
#   ...
#   [252 200  54]
#   [252 200  54]
#   [249 197  51]]
#
#  [[255 207  62]
#   [255 207  62]
#   [253 202  57]
#   ...
#   [254 202  56]
#   [254 202  56]
#   [248 196  50]]
#
#  [[231 180  35]
#   [245 194  49]
#   [251 200  55]
#   ...
#   [255 205  59]
#   [255 205  59]
#   [248 196  50]]]
